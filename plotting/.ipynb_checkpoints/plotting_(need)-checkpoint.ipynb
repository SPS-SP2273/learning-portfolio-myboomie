# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'
plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('X vs Y') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# ### Things to note

# %% [markdown]
# #### 0. Create a plot: `plt.plot(x,y,label,color,linestyle)`

# %% [markdown]
# Without the `plt.plot()`, we not passing the points (x,y) into the plot. It will look empty!

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
# plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'
plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('X vs Y') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### 1. Labelling x-axis: `plt.xlabel('....')`, y-axis: `plt.ylabel('...')`

# %% [markdown]
# Copy the previous but as I comment out the line `plt.xlabel()`, the x-axis would not be labeled

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

# plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('X vs Y') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# Similarly, commenting out the line `plt.ylabel()` will empty the label of y-axis

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
# plt.ylabel('y-values') #label the y-axis
plt.title('X vs Y') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# ### 2. Add title to the plot: `plt.title('...')`

# %% [markdown]
# By commenting out the line `plt.title('...')`, the title of the plot disappears.

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
# plt.title('X vs Y') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# Change the title to another one: `This is a plot!`

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('This is a plot!') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# #### 3. Adding legend to the plot: `plt.legend()`

# %% [markdown]
# Without the `plt.legend()`, there will not be a box that includes legend for our equations/plots

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('This is a plot!') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
# plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Now, there is a legend!') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend() #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# **Specifying the location of the legend box via `loc`: `plt.legend(loc = '...')`**. There are certain locations as such:
# - upper right corner: `loc = 'upper right'`
# - upper left corner: `loc = 'upper left'`
# - lower right coner: `loc = 'lower right'`
# - lower left corner: `loc = 'lower left'`

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Legend at upper left corner') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Legend at upper right corner') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='upper right') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Legend at lower right corner') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='lower right') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Legend at lower left corner') #label the plot
plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='lower left') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# #### 4. Adding a grid: `plt.grid()`

# %% [markdown]
# Now, we will not have a grid but a white background if we turn off the line `pltg.grid()`

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Y vs X') #label the plot
# plt.grid(alpha=.25) #add grid and make it transparent with .25 degree
plt.legend(loc='lower right') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# But now, the grid is quite dark by default as we turn on the grid by having the line `plt.grid()`

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Legend at lower right corner') #label the plot
plt.grid() #add grid and make it transparent with .25 degree
plt.legend(loc='lower right') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# We can change the transparency of the grid to make it more aesthetic with `alpha` (from 0 to 1) variable in `plt.grid(alpha =..)`. The closer the value of `alpha` to 1, the darker the grid is.

# %%
import matplotlib.pyplot as plt
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6] #create a series of x variables
y_1 = [0, 2, 4, 6, 8, 10, 12] #create a series of corresponding y variables
y_2 = [0, 3, 6, 9, 12, 15, 18] #create another series of correspoding y variables

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Alpha = 0.5') #label the plot
plt.grid(alpha=.5) #add grid and make it transparent with .25 degree
plt.legend(loc='lower right') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# Let's start plotting
plt.plot(x, y_1, label='Y values',color='red', linestyle='dashed')
#plt.plot() starts a plot with x and y1 variables, label it with 'Y Values', the line will be of color 'red', and the linestyle will be 'dash'

plt.xlabel('x-values') #label the x-axis
plt.ylabel('y-values') #label the y-axis
plt.title('Alpha = 0.2') #label the plot
plt.grid(alpha=.2) #add grid and make it transparent with .25 degree
plt.legend(loc='lower right') #add a legend to the plot
plt.show() #show the plot instead of giving us an address of this plot in the storage memory

# %% [markdown]
# ### Things to note:

# %% [markdown]
# 1. Abbreviations of arguments:
# |Long form|Abbreviation|
# |:--:|:--:|
# |`color`|`c`|
# |`linestyle`|`ls`|
# |`linewidth`|'=`lw`|

# %% [markdown]
# 2. Include `plt.show()` to provide us a figure instead of a memory address

# %% [markdown]
# 3. The plotting functions usually have default values for the styling parameters

# %%
plt.plot(x, y_1, y_2)

# %% [markdown]
# 4. We can split the code for readability

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# We can add multiple plots in the current figure by simplying adding another `plt.plot(x,y,...)`

# %%
import numpy as np
x = np.arange(1,10,1)
y1 = x*2+3
y2 = x**2+3

plt.plot(x,y1, label ='$ y = 2x + 3$')
plt.plot(x,y2, label ='$ y = x^2 + 3$')
plt.legend()
plt.title('Some mathematical plots')
plt.grid(alpha = .25)
plt.show()

# %% [markdown]
# ## 1.3 Yet another plot but with error bars: `plt.errorbar(x, y, xerr, yerr, ...)`

# %%
import numpy as np
x = np.arange(1,10,1)
y1 = x*2+3
y2 = x**2+3
y3 = x**3 + 3
x_err, y_err = .25, .75

plt.plot(x,y1, label ='$ y = 2x + 3$')
plt.plot(x,y2, label ='$ y = x^2 + 3$')
plt.errorbar(x,y3, xerr = x_err, yerr = y_err, c = 'green', label = 'With error bars')
plt.legend()
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Some mathematical plots')
plt.grid(alpha = .25)
plt.show()

# %% [markdown]
# # 2 Better with NumPy

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.arange(-5,5,.01)
plt.plot(x, np.sin(x), label ='$ sin(x) $', color = 'red')
plt.plot(x,np.cos(x), label = '$ cos(x)$', color = 'blue')
plt.legend()
plt.grid(alpha = 0.5)
plt.title('Sin and cos functions')
plt.show()

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# Use `twinx()` to share x-axis but have another y-axis on the right. This can be useful when we have 2 line plots with different y-axis range but similar x-axis range

# %%
x = np.arange(-5,5,.01)
plt.plot(x, np.sin(x), label ='$ sin(x) $', color = 'red')
plt.legend(loc = 'upper left')

plt.twinx()

plt.plot(x,np.cos(x), label = '$ cos(x)$', color = 'blue')
plt.legend()

plt.grid(alpha = 0.5)
plt.title('Sin and cos functions')
plt.show()

# %% [markdown]
# ### Things to note

# %% [markdown]
# 1. We now have two `legend()` calls, one for each axis.
# 2. Use `np.linspace()` to specify the number of data points within a specified range (included) we want

# %%
xtry = np.linspace(0,10,5) 
#create an array that starts from 0 and ends with 10 in which there are 5 elements inside the array
xtry
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %% [markdown]
# # 3 Saving to disc: `plt.savefig()`

# %% [markdown]
# We can save the plot to our current folder by `plt.savefig()`, inside the parenthesis, we can choose to save the image with name `ABC` by specifying it as arguments in `plt.savefig('ABC')`

# %% [markdown]
# We can also specify resolution by use dots-per-inch (`dpi`): `plt.savefig('ABC', dpi = 150)`

# %% [markdown]
# If you want it saved elsewhere, specify the path in more detail

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
data = 'FEV.csv'
import pandas as pd
df = pd.read_csv(data)
df
# Out:
#         ID  Age   FEV   Hgt  Sex  Smoke  height
# 0      301    9  1.71  57.0    0      0    1.45
# 1      451    8  1.72  67.5    0      0    1.71
# 2      501    7  1.72  54.5    0      0    1.38
# 3      642    9  1.56  53.0    1      0    1.35
# 4      901    9  1.90  57.0    1      0    1.45
# ..     ...  ...   ...   ...  ...    ...     ...
# 649  73041   16  4.27  67.0    1      1    1.70
# 650  73042   15  3.73  68.0    1      1    1.73
# 651  73751   18  2.85  60.0    0      0    1.52
# 652  75852   16  2.80  63.0    0      1    1.60
# 653  77151   15  3.21  66.5    0      0    1.69
#
# [654 rows x 7 columns]

# %%
#plot the FEV 
plt.scatter(df['FEV'], df['Hgt'], color = 'red', label = 'Hgt vs FEV')
plt.legend()
plt.grid(alpha = .5)
plt.show()

# %% [markdown]
# Let’s add a line to highlight the trend shown by the data. This can be done using Linear Regression in `seaborn` package

# %%
#plot the FEV 
import seaborn as sb
sb.regplot(data = df,x = 'FEV', y = 'Hgt') #Add a straight line for trend

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
with plt.xkcd():
    plt.scatter(df['FEV'], df['Hgt'], color = 'red', label = 'Hgt vs FEV')
    plt.legend()
    plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Humor Sans' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# ...

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')
plt.scatter(df['FEV'], df['Hgt'], color = 'red', label = 'Hgt vs FEV')
plt.legend()
plt.show()
